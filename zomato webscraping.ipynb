# %% [markdown]
# ## Final Zomato code for webscraping

# %%
import time                #for using sleep in order to load website
from selenium import webdriver    #webdriver for loading webpages
from selenium.webdriver.common.by import By   # for locating elements in the webpage
from selenium.common.exceptions import NoSuchElementException # For handling exceptions
import pandas as pd # Pandas data manipulation library for storing data as CSV file

driver = webdriver.Firefox()  #instance of Firefox WebDriver is created
# driver.maximize_window() #maximize the window size

##### Web scrapper for infinite scrolling page #####
driver.get("https://www.zomato.com/coimbatore")    #The driver.get method will navigate to a page given by the URL
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script(f"window.scrollTo(0, {screen_height}*{i});")  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break


### Extract restaurant details once we reach the end of dynamic Zomato webpage ####
rest_list = []  ## Restaurant list variable to which dictionary of each restaurant details will be appended

row = 10 # row variable for iterating Restaurant elements XPATH (***This has to checked manually in the webpage manually before running this script since it will also change dynamically sometimes***)
column = 1 # column variable for iterating Restaurant elements XPATH

while True:  #infinite loop initiation
# Restaurants are diplayed in the website similar to (n-rows x 3-columns) matrix. So basically we are indexing the XPATH link using row and column cariable.
    if column > 3:   #Since 3 restaurants are displayed in 1 row, this condition is necessary to restrict the column within 3.
        row += 1     # Row is also incremented to 1 to move on to the next row when column variable completed 3.
        column = 1   # we also need the reset the column back to 1 

    try:
        rest_name = driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[1]/h4").text  #Returns retaurant name from corresponding XPATH element 
    except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
        rest_name = None

    try:
        rating = driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[1]/div/div/div/div/div/div[1]").text #Returns retaurant rating from corresponding XPATH element
    except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
        rating = None

    try:
        offer_ = driver.find_elements(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[1]/div[3]/p") ##Returns list of Offers from corresponding XPATH elements
        if len(offer_) > 1:  #checking the length if there are any multiple offers
            pro_offer = offer_[0].text #Zomato offer for only pro users
            offer = offer_[1].text # Zomato offer for all users
        else:                      
            pro_offer = None
            offer = driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[1]/div[3]/p").text #Returns offer from corresponding XPATH element
    except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
        pro_offer = None
        offer = None

    try:
        del_time = driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[1]/p").text #Returns delivery time from corresponding XPATH element
    except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
        del_time = None

    try:
        category = driver.find_element(By.XPATH,f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[2]/p[1]").text #Returns restaurant category from corresponding XPATH element
    except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
        category = None

    try:
        cfo = driver.find_element(By.XPATH,f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[2]/p[2]").text #Returns *cost for one* from corresponding XPATH element
    except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
        cfo = None

    try:
        roc = driver.find_element(By.XPATH,f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[4]/div/div/div/p").text #Returns *recent orders count* from corresponding XPATH element
    except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
        roc = None

    if (rest_name or rating or offer or del_time or category or cfo or roc) == None:     #This is the infinite loop breaker. When all the variables is none, loop breaks
        break


    rest_item = {                         #dictionary for storing the restaurant feature variables
        'rest_name' : rest_name,
        'rating' : rating,
        'pro_offer': pro_offer,
        'offer' : offer,
        'del_time' : del_time,
        'category' : category,
        'cost_for_one' : cfo,
        'recent_orders_count': roc
    }

    rest_list.append(rest_item)     #dictionsry will be appended to this rest_list

    column += 1 # column is incremented
    
df = pd.DataFrame(rest_list)    #dataframe creation from the list
df.to_csv("Zomato_rest_df.csv", index = False) #Saving as CSV file

# %%
df
# Out:
#                              rest_name rating          pro_offer    offer  \
# 0                            Taco Bell    3.8               None  60% OFF
# 1                  HMR - Grand Kitchen    4.1               None  40% OFF
# 2                      Barbeque Nation    3.9               None  50% OFF
# 3    Sree Annapoorna Sree Gowrishankar    4.2               None  20% OFF
# 4      China Valley Chinese Restaurant    3.7  Pro extra 15% OFF  50% OFF
# ..                                 ...    ...                ...      ...
# 565                  Little Owl's Cafe      -               None     None
# 566                             Zwarma    3.9               None  20% OFF
# 567                        Gt 12 To 12    3.2               None  50% OFF
# 568           A.R.C Sasi's Chat & More    4.0               None     None
# 569                            SR Cafe    3.9               None     None
#
#     del_time                                           category  cost_for_one  \
# 0     35 min               Mexican, Fast Food, Wraps, Beverages  ₹150 for one
# 1     29 min  South Indian, Hyderabadi, Chinese, Biryani, De...  ₹150 for one
# 2     45 min    BBQ, Chinese, North Indian, Beverages, Desserts  ₹150 for one
# 3     29 min  South Indian, North Indian, Chinese, Beverages...  ₹150 for one
# 4     38 min                                   Chinese, Seafood  ₹150 for one
# ..       ...                                                ...           ...
# 565     None              Fast Food, Desserts, Beverages, Shake  ₹100 for one
# 566     None                                      Lebanese, BBQ  ₹100 for one
# 567   41 min              Fast Food, Mughlai, Lebanese, Chinese  ₹100 for one
# 568     None                                          Fast Food  ₹100 for one
# 569     None  Fast Food, Chinese, North Indian, Street Food,...  ₹100 for one
#
#                         recent_orders_count
# 0    1200+ orders placed from here recently
# 1    4125+ orders placed from here recently
# 2     550+ orders placed from here recently
# 3    5150+ orders placed from here recently
# 4    1675+ orders placed from here recently
# ..                                      ...
# 565                                    None
# 566    75+ orders placed from here recently
# 567   225+ orders placed from here recently
# 568   300+ orders placed from here recently
# 569   150+ orders placed from here recently
#
# [570 rows x 8 columns]

# %%
df.to_csv("rest_df_12_10_PM.csv", index = False)

# %% [markdown]
# ## Converting into scalable code using classes

# %%
import time         #for using sleep in order to load website
from selenium import webdriver    #webdriver for loading webpages
from selenium.webdriver.common.by import By   # for locating elements in the webpage
from selenium.common.exceptions import NoSuchElementException # For handling exceptions
import pandas as pd # Pandas data manipulation library for storing data as CSV file


class zomato_scrap:
    def __init__(self, city) -> None:
        self.city = city
        

    def open_browser(self):
        self.driver = webdriver.Firefox()  #instance of Firefox WebDriver is created
        
    def load_url(self):
        self.open_browser()
        self.driver.get(f"https://www.zomato.com/{self.city}")    #The driver.get method will navigate to a page given by the URL
        time.sleep(2)  # Allow 2 seconds for the web page to open

    def infinite_scroll(self):
        self.load_url()
        scroll_pause_time = 1 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
        screen_height = self.driver.execute_script("return window.screen.height;")   # get the screen height of the web
        i = 1
        ##### Web scrapper for infinite scrolling page #####
        while True:
            # scroll one screen height each time
            self.driver.execute_script(f"window.scrollTo(0, {screen_height}*{i});")  
            i += 1
            time.sleep(scroll_pause_time)
            # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
            scroll_height = self.driver.execute_script("return document.body.scrollHeight;")  
            # Break the loop when the height we need to scroll to is larger than the total scroll height
            if (screen_height) * i > scroll_height:
                break

    def extract_data(self):
        self.infinite_scroll()
        ### Extract restaurant details once we reach the end of dynamic Zomato webpage ####
        rest_list = []  ## Restaurant list variable to which dictionary of each restaurant details will be appended

        row = 10 # row variable for iterating Restaurant elements XPATH (***This has to checked manually in the webpage manually before running this script since it will also change dynamically sometimes***)
        column = 1 # column variable for iterating Restaurant elements XPATH

        while True:  #infinite loop initiation
            # Restaurants are diplayed in the website similar to (n-rows x 3-columns) matrix. So basically we are indexing the XPATH link using row and column cariable.
            if column > 3:   #Since 3 restaurants are displayed in 1 row, this condition is necessary to restrict the column within 3.
                row += 1     # Row is also incremented to 1 to move on to the next row when column variable completed 3.
                column = 1   # we also need the reset the column back to 1 

            try:
                rest_name = self.driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[1]/h4").text  #Returns retaurant name from corresponding XPATH element 
            except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
                rest_name = None

            try:
                rating = self.driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[1]/div/div/div/div/div/div[1]").text #Returns retaurant rating from corresponding XPATH element
            except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
                rating = None

            try:
                offer_ = self.driver.find_elements(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[1]/div[3]/p") ##Returns list of Offers from corresponding XPATH elements
                if len(offer_) > 1:  #checking the length if there are any multiple offers
                    pro_offer = offer_[0].text #Zomato offer for only pro users
                    offer = offer_[1].text # Zomato offer for all users
                else:                      
                    pro_offer = None
                    offer = self.driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[1]/div[3]/p").text #Returns offer from corresponding XPATH element
            except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
                pro_offer = None
                offer = None

            try:
                del_time = self.driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[1]/p").text #Returns delivery time from corresponding XPATH element
            except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
                del_time = None

            try:
                category = self.driver.find_element(By.XPATH,f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[2]/p[1]").text #Returns restaurant category from corresponding XPATH element
            except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
                category = None

            try:
                cfo = self.driver.find_element(By.XPATH,f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[2]/p[2]").text #Returns *cost for one* from corresponding XPATH element
            except NoSuchElementException: #If the XPATH isn't found this exception is raised and handled
                cfo = None

            try:
                roc = self.driver.find_element(By.XPATH,f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[4]/div/div/div/p").text #Returns *recent orders count* from corresponding XPATH element
            except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
                roc = None

            if (rest_name or rating or offer or del_time or category or cfo or roc) == None:     #This is the infinite loop breaker. When all the variables is none, loop breaks
                break


            rest_item = {                         #dictionary for storing the restaurant feature variables
                'rest_name' : rest_name,
                'rating' : rating,
                'pro_offer': pro_offer,
                'offer' : offer,
                'del_time' : del_time,
                'category' : category,
                'cost_for_one' : cfo,
                'recent_orders_count': roc
            }

            rest_list.append(rest_item)     #dictionsry will be appended to this rest_list

            column += 1 # column is incremented

        return rest_list    


    def convert_csv(self):
        df = pd.DataFrame(self.extract_data())    #dataframe creation from the list
        df.to_csv(f"Zomato_rest_{self.city}_df.csv", index = False) #Saving as CSV file


covai = zomato_scrap("coimbatore")
covai.convert_csv()

# %% [markdown]
# ### Restaurant coordinates extraction

# %%
import time         #for using sleep in order to load website
from selenium import webdriver    #webdriver for loading webpages
from selenium.webdriver.common.by import By   # for locating elements in the webpage
from selenium.common.exceptions import NoSuchElementException # For handling exceptions
import pandas as pd # Pandas data manipulation library for storing data as CSV file
from datetime import datetime
from pytz import timezone 


driver = webdriver.Firefox()
url = "https://www.zomato.com/coimbatore"
driver.get(url)  #The driver.get method will navigate to a page given by the URL
time.sleep(2)  # Allow 2 seconds for the web page to open

scroll_pause_time = 1 # You can set your own pause time. My laptop is a bit slow so I use 1 sec
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script(f"window.scrollTo(0, {screen_height}*{i});")  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
### Extract restaurant details once we reach the end of dynamic Zomato webpage ####
restaurant_list = []  ## Restaurant list variable to which dictionary of each restaurant details will be appended

row = 10 # row variable for iterating Restaurant elements XPATH (***This has to checked manually in the webpage manually before running this script since it will also change dynamically sometimes***)
column = 1 # column variable for iterating Restaurant elements XPATH

while True:  #infinite loop initiation
# Restaurants are diplayed in the website similar to (n-rows x 3-columns) matrix. So basically we are indexing the XPATH link using row and column cariable.
    if column > 3:   #Since 3 restaurants are displayed in 1 row, this condition is necessary to restrict the column within 3.
        row += 1     # Row is also incremented to 1 to move on to the next row when column variable completed 3.
        column = 1   # we also need the reset the column back to 1 

    try:
        restaurant_name = driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]/div[1]/h4").text  #Returns retaurant name from corresponding XPATH element 
    except NoSuchElementException:  #If the XPATH isn't found this exception is raised and handled
        restaurant_name = None

    try:
        href_element = driver.find_element(By.XPATH, f"/html/body/div[1]/div/div[{row}]/div/div[{column}]/div/div/a[2]")
        restaurant_url = href_element.get_attribute('href')
    except NoSuchElementException:
        restaurant_url = None

    
    if (restaurant_name or restaurant_url) == None:
        break
    
    restaurant_item =  {'rest_name': restaurant_name,
                        'restaurant_url': restaurant_url}

    restaurant_list.append(restaurant_item)
    column += 1

df = pd.DataFrame(restaurant_list)

# %%
df.head()
# Out:
#                            rest_name  \
# 0                    Barbeque Nation
# 1                HMR - Grand Kitchen
# 2    China Valley Chinese Restaurant
# 3  Sree Annapoorna Sree Gowrishankar
# 4                         Richy Rich
#
#                                       restaurant_url  \
# 0  https://www.zomato.com/coimbatore/barbeque-nat...
# 1  https://www.zomato.com/coimbatore/hmr-grand-ki...
# 2  https://www.zomato.com/coimbatore/china-valley...
# 3  https://www.zomato.com/coimbatore/sree-annapoo...
# 4  https://www.zomato.com/coimbatore/richy-rich-r...
#
#                                         location_url
# 0  https://www.google.com/maps/dir/?api=1&destina...
# 1  https://www.google.com/maps/dir/?api=1&destina...
# 2  https://www.google.com/maps/dir/?api=1&destina...
# 3  https://www.google.com/maps/dir/?api=1&destina...
# 4  https://www.google.com/maps/dir/?api=1&destina...

# %%
map_url = []

for url in df['restaurant_url']:
    driver.get(url)
    time.sleep(2)
    try:
        direction_element = driver.find_element(By.XPATH, f"/html/body/div[1]/div/main/div/section[3]/div[1]/section/a")
        location_url = direction_element.get_attribute('href')
    except:
        location_url = None
    
    map_url.append(location_url)

# %%
df['location_url'] = map_url

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rest_name       535 non-null    object
#  1   restaurant_url  535 non-null    object
#  2   location_url    534 non-null    object
# dtypes: object(3)
# memory usage: 12.7+ KB

# %%
df = df.dropna()

# %%
df["location_url"][2]
# Out:
# 'https://www.google.com/maps/dir/?api=1&destination=10.9981130168,76.9825409353'

# %%
def url_to_gps(location_url):
    coord = location_url.split('=')[2].split(',')
    lat = coord[0]
    long = coord[1]
    return lat,long

# %%
df['lat'],df['long'] = np.vectorize(url_to_gps)(df["location_url"])
# Out:
# C:\Users\naveen\anaconda3\envs\PythonForMLandDS\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df = df.drop(['restaurant_url', 'location_url'], axis = 1)

# %%
df.to_csv('zomato_restaurant_gps_coordinates.csv',index=False)

# %%
# Out:
# https://www.zomato.com/coimbatore/china-valley-chinese-restaurant-ramanathapuram/order
# https://www.zomato.com/coimbatore/hmr-grand-kitchen-gandhipuram/order
# https://www.zomato.com/coimbatore/hangout-saibaba-colony/order
# https://www.zomato.com/coimbatore/sree-annapoorna-sree-gowrishankar-1-gandhipuram/order
# https://www.zomato.com/coimbatore/bakingo-saibaba-colony/order
# https://www.zomato.com/coimbatore/sree-subbu-mess-gandhipuram/order
# https://www.zomato.com/coimbatore/nin-hao-saibaba-colony/order
# https://www.zomato.com/coimbatore/abitha-biriyani-hotel-ukkadam/order
# https://www.zomato.com/coimbatore/cafe-quilon-ramanathapuram/order
# https://www.zomato.com/coimbatore/haribhavanam-gandhipuram/order
# https://www.zomato.com/coimbatore/haribhavanam-peelamedu/order
# https://www.zomato.com/coimbatore/hotel-maa-race-course/order
# https://www.zomato.com/coimbatore/ss-hotel-gandhipuram/order
# https://www.zomato.com/coimbatore/hotel-chola-1-gandhipuram/order
# https://www.zomato.com/coimbatore/shree-anandhaas-1-gandhipuram/order
# https://www.zomato.com/coimbatore/hotel-chola-peelamedu/order
# https://www.zomato.com/coimbatore/kfc-peelamedu/order
# https://www.zomato.com/coimbatore/dindigul-thalappakatti-1-gandhipuram/order
# https://www.zomato.com/coimbatore/ss-hyderabad-biryani-gandhipuram/order
# https://www.zomato.com/coimbatore/dominos-pizza-nehru-stadium/order
# https://www.zomato.com/coimbatore/denmarrk-drive-inn-restaurant-ganapathy/order
# https://www.zomato.com/coimbatore/shree-aksshayam-peelamedu/order
# https://www.zomato.com/coimbatore/alif-paradise-biriyani-peelamedu/order
# https://www.zomato.com/coimbatore/burma-bhai-hotel-nehru-stadium/order
# https://www.zomato.com/coimbatore/valarmathi-kongunaatu-samayal-race-course/order
# https://www.zomato.com/coimbatore/thalassery-restaurant-1-ukkadam/order
# https://www.zomato.com/coimbatore/adyar-ananda-bhavan-1-gandhipuram/order
# https://www.zomato.com/coimbatore/ananth-bhavan-rs-puram/order
# https://www.zomato.com/coimbatore/sri-velan-chettinadu-mess-peelamedu/order
# https://www.zomato.com/coimbatore/chennais-biriyani-house-rs-puram/order
# https://www.zomato.com/coimbatore/hotel-delhi-dharbarr-peelamedu/order
# https://www.zomato.com/coimbatore/malabar-restaurant-gandhipuram/order
# https://www.zomato.com/coimbatore/burger-king-rs-puram/order
# https://www.zomato.com/coimbatore/hotel-chola-1-ramanathapuram/order
# https://www.zomato.com/coimbatore/ammayi-veedu-pot-cook-gandhipuram/order
# https://www.zomato.com/coimbatore/shahi-grill-peelamedu/order
# https://www.zomato.com/coimbatore/dindigul-venu-biryani-gandhipuram/order
# https://www.zomato.com/coimbatore/selvam-chettinad-mess-peelamedu/order
# https://www.zomato.com/coimbatore/mr-moorthy-chettinadu-ganapathy/order
# https://www.zomato.com/coimbatore/sri-ganapathy-mess-peelamedu/order
# https://www.zomato.com/coimbatore/fb-cakes-gandhipuram/order
# https://www.zomato.com/coimbatore/ambur-star-briyani-rs-puram/order
# https://www.zomato.com/coimbatore/biryani-in-bucket-gandhipuram/order
# https://www.zomato.com/coimbatore/keventers-milkshakes-desserts-rs-puram/order
# https://www.zomato.com/coimbatore/goparatha-1-lakshmi-mills/order
# https://www.zomato.com/coimbatore/haaji-biriyani-gandhipuram/order
# https://www.zomato.com/coimbatore/ponni-restaurant-lakshmi-mills/order
# https://www.zomato.com/coimbatore/hyderabad-biryani-1-gandhipuram/order
# https://www.zomato.com/coimbatore/rhr-restaurant-race-course/order
# https://www.zomato.com/coimbatore/hotel-kannappa-ganapathy/order
# https://www.zomato.com/coimbatore/aasife-biriyani-saravanampatty/order
# https://www.zomato.com/coimbatore/seethalakshmi-veg-hotel-rs-puram/order
# https://www.zomato.com/coimbatore/a-1-briyani-hotel-1-saibaba-colony/order
# https://www.zomato.com/coimbatore/alam-grilled-wraps-rs-puram/order
# https://www.zomato.com/coimbatore/pizza2go4u-ramanathapuram/order
# https://www.zomato.com/coimbatore/richy-rich-race-course/order
# https://www.zomato.com/coimbatore/cakebee-saibaba-colony/order
# https://www.zomato.com/coimbatore/sri-angannan-biriyani-hotel-town-hall/order
# https://www.zomato.com/coimbatore/kanchan-kitchens-rs-puram/order
# https://www.zomato.com/coimbatore/nightout-lakshmi-mills/order
# https://www.zomato.com/coimbatore/cock-ra-co-sivanadha-colony/order
# https://www.zomato.com/coimbatore/meat-and-eat-ganapathy/order
# https://www.zomato.com/coimbatore/hotel-junior-kuppanna-peelamedu/order
# https://www.zomato.com/coimbatore/sree-ram-mess-peelamedu/order
# https://www.zomato.com/coimbatore/courtallam-border-rahmath-kadai-race-course/order
# https://www.zomato.com/coimbatore/woow-biriyani-ganapathy/order
# https://www.zomato.com/coimbatore/thirupathi-mess-ramanathapuram/order
# https://www.zomato.com/coimbatore/kovai-biryani-hotel-rs-puram/order
# https://www.zomato.com/coimbatore/hotel-shri-chola-saibaba-colony/order
# https://www.zomato.com/coimbatore/amh-ambur-star-biriyani-ganapathy/order
# https://www.zomato.com/coimbatore/geetha-cafe-race-course/order
# https://www.zomato.com/coimbatore/sri-raja-biryani-hotel-gandhipuram/order
# https://www.zomato.com/coimbatore/d-r-biriyani-rs-puram/order
# https://www.zomato.com/coimbatore/chennai-pazhamudir-nilayam-peelamedu/order
# https://www.zomato.com/coimbatore/pizza-hut-1-rs-puram/order
# https://www.zomato.com/coimbatore/oyalo-pizza-ganapathy/order
# https://www.zomato.com/coimbatore/msr-biriyani-hotel-ramanathapuram/order
# https://www.zomato.com/coimbatore/shree-anandhaas-sweets-snacks-gandhipuram/order
# https://www.zomato.com/coimbatore/kokkarako-biriyani-and-fast-food-saibaba-colony/order
# https://www.zomato.com/coimbatore/zucca-pizzeria-peelamedu/order
# https://www.zomato.com/coimbatore/srkp-chettinad-mess-peelamedu/order
# https://www.zomato.com/coimbatore/kwality-walls-frozen-dessert-and-ice-cream-shop-ganapathy/order
# https://www.zomato.com/coimbatore/subway-peelamedu/order
# https://www.zomato.com/coimbatore/hotel-chola-1-rs-puram/order
# https://www.zomato.com/coimbatore/ibaco-rs-puram/order
# https://www.zomato.com/coimbatore/mr-grill-lakshmi-mills/order
# https://www.zomato.com/coimbatore/aroma-bakery-nehru-stadium/order
# https://www.zomato.com/coimbatore/sri-balaji-arul-jothi-ramanathapuram/order
# https://www.zomato.com/coimbatore/shree-renuga-mess-1-peelamedu/order
# https://www.zomato.com/coimbatore/hotel-chola-rs-puram/order
# https://www.zomato.com/coimbatore/agarwals-the-sweet-shop-rs-puram/order
# https://www.zomato.com/coimbatore/sita-paani-ganapathy/order
# https://www.zomato.com/coimbatore/behrouz-biryani-rs-puram/order
# https://www.zomato.com/coimbatore/barbeque-nation-town-hall/order
# https://www.zomato.com/coimbatore/royal-biriyani-fastfood-gandhipuram/order
# https://www.zomato.com/coimbatore/vaskas-biriyani-peelamedu/order
# https://www.zomato.com/coimbatore/the-punjab-express-rs-puram/order
# https://www.zomato.com/coimbatore/the-cake-point-ganapathy/order
# https://www.zomato.com/coimbatore/hotel-chola-lakshmi-mills/order
# https://www.zomato.com/coimbatore/sms-hotels-peelamedu/order
# https://www.zomato.com/coimbatore/sree-velu-biriyani-ganapathy/order
# https://www.zomato.com/coimbatore/sree-subbu-mess-race-course/order
# https://www.zomato.com/coimbatore/taco-bell-1-ganapathy/order
# https://www.zomato.com/coimbatore/eatfit-race-course/order
# https://www.zomato.com/coimbatore/mi-pizza-rs-puram/order
# https://www.zomato.com/coimbatore/sri-krishna-bhavan-restaurant-town-hall/order
# https://www.zomato.com/coimbatore/royal-biriyani-fast-food-saibaba-colony/order
# https://www.zomato.com/coimbatore/hotel-atchaya-rs-puram/order
# https://www.zomato.com/coimbatore/sree-annapoorna-sweets-savouries-gandhipuram/order
# https://www.zomato.com/coimbatore/the-red-box-peelamedu/order
# https://www.zomato.com/coimbatore/fb-cakes-ramanathapuram/order
# https://www.zomato.com/coimbatore/agarwal-sweet-palace-peelamedu/order
# https://www.zomato.com/coimbatore/nic-natural-ice-creams-peelamedu/order
# https://www.zomato.com/coimbatore/fipola-grill-house-ganapathy/order
# https://www.zomato.com/coimbatore/doods-bites-peelamedu/order
# https://www.zomato.com/coimbatore/the-belgian-waffle-co-peelamedu/order
# https://www.zomato.com/coimbatore/kanakathara-ganapathy/order
# https://www.zomato.com/coimbatore/pannaiyar-biriyani-saibaba-colony/order
# https://www.zomato.com/coimbatore/ubq-by-barbeque-nation-town-hall/order
# https://www.zomato.com/coimbatore/covai-anganan-biriyani-house-lakshmi-mills/order
# https://www.zomato.com/coimbatore/polar-bear-saibaba-colony/order
# https://www.zomato.com/coimbatore/hotel-safaire-ukkadam/order
# https://www.zomato.com/coimbatore/selvamani-canteen-town-hall/order
# https://www.zomato.com/coimbatore/sri-trupthi-mess-ramanathapuram/order
# https://www.zomato.com/coimbatore/hideout-cafe-peelamedu/order
# https://www.zomato.com/coimbatore/boomerang-nehru-stadium/order
# https://www.zomato.com/coimbatore/faasos-rs-puram/order
# https://www.zomato.com/coimbatore/sri-mookambika-mess-rs-puram/order
# https://www.zomato.com/coimbatore/agarwal-sweet-palace-1-rs-puram/order
# https://www.zomato.com/coimbatore/my-place-restaurant-lakshmi-mills/order
# https://www.zomato.com/coimbatore/grand-cafe-race-course/order
# https://www.zomato.com/coimbatore/shree-pappu-restaurant-ganapathy/order
# https://www.zomato.com/coimbatore/chitra-homely-foods-gandhipuram/order
# https://www.zomato.com/coimbatore/hotel-raahava-chettinad-ganapathy/order
# https://www.zomato.com/coimbatore/ammas-pastries-1-gandhipuram/order
# https://www.zomato.com/coimbatore/lunchbox-meals-and-thalis-rs-puram/order
# https://www.zomato.com/coimbatore/hotel-arrunnachala-peelamedu/order
# https://www.zomato.com/coimbatore/all-seasons-vegetarian-delecacies-saibaba-colony/order
# https://www.zomato.com/coimbatore/junior-sri-engannan-biriyani-saibaba-colony/order
# https://www.zomato.com/coimbatore/mg-mess-peelamedu/order
# https://www.zomato.com/coimbatore/taste-of-malabar-ukkadam/order
# https://www.zomato.com/coimbatore/kovai-juice-corner-peelamedu/order
# https://www.zomato.com/coimbatore/covai-grills-peelamedu/order
# https://www.zomato.com/coimbatore/arunachala-ganapathy/order
# https://www.zomato.com/coimbatore/linda-saibaba-colony/order
# https://www.zomato.com/coimbatore/hotel-sri-lakshmi-bhavnam-ganapathy/order
# https://www.zomato.com/coimbatore/sri-krishna-sweets-1-gandhipuram/order
# https://www.zomato.com/coimbatore/miami-juice-world-town-hall/order
# https://www.zomato.com/coimbatore/sri-sai-cafe-race-course/order
# https://www.zomato.com/coimbatore/falooda-hut-1-ramanathapuram/order
# https://www.zomato.com/coimbatore/bon-bon-rs-puram/order
# https://www.zomato.com/coimbatore/aligarh-house-race-course/order
# https://www.zomato.com/coimbatore/saravanas-kitchen-peelamedu/order
# https://www.zomato.com/coimbatore/the-side-dish-company-peelamedu/order
# https://www.zomato.com/coimbatore/bowld-peelamedu/order
# https://www.zomato.com/coimbatore/lmn-hajiyaar-biriyani-hotel-ukkadam/order
# https://www.zomato.com/coimbatore/red-door-race-course/order
# https://www.zomato.com/coimbatore/arthi-chettinad-ramanathapuram/order
# https://www.zomato.com/coimbatore/amul-ice-cream-ganapathy/order
# https://www.zomato.com/coimbatore/the-good-bowl-rs-puram/order
# https://www.zomato.com/coimbatore/jr-cakes-bakes-peelamedu/order
# https://www.zomato.com/coimbatore/yumlane-pizza-race-course/order
# https://www.zomato.com/coimbatore/burger-bytes-rs-puram/order
# https://www.zomato.com/coimbatore/yari-saibaba-colony/order
# https://www.zomato.com/coimbatore/chai-kings-rs-puram/order
# https://www.zomato.com/coimbatore/pattukkottai-kamatchhi-mess-rs-puram/order
# https://www.zomato.com/coimbatore/mr-kolambu-saibaba-colony/order
# https://www.zomato.com/coimbatore/shree-aboorvaas-pure-veg-restaurant-saibaba-colony/order
# https://www.zomato.com/coimbatore/chai-kings-peelamedu/order
# https://www.zomato.com/coimbatore/a-to-z-palamudir-nilayam-gandhipuram/order
# https://www.zomato.com/coimbatore/big-fat-burger-ramanathapuram/order
# https://www.zomato.com/coimbatore/king-kong-biryani-sivanadha-colony/order
# https://www.zomato.com/coimbatore/oceana-hotel-saibaba-colony/order
# https://www.zomato.com/coimbatore/al-maas-biriyani-house-ramanathapuram/order
# https://www.zomato.com/coimbatore/vijay-chettinad-mess-ramanathapuram/order
# https://www.zomato.com/coimbatore/boom-cafe-2-peelamedu/order
# https://www.zomato.com/coimbatore/kailash-parbat-5-rs-puram/order
# https://www.zomato.com/coimbatore/ramesh-mess-1-saibaba-colony/order
# https://www.zomato.com/coimbatore/live-cakes-1-peelamedu/order
# https://www.zomato.com/coimbatore/raj-bhavans-lunchbox-gandhipuram/order
# https://www.zomato.com/coimbatore/oven-fresh-rs-puram/order
# https://www.zomato.com/coimbatore/just-bake-rs-puram/order
# https://www.zomato.com/coimbatore/burger-ka-baap-peelamedu/order
# https://www.zomato.com/coimbatore/thambiyannan-biriyani-hotel-gandhipuram/order
# https://www.zomato.com/coimbatore/fort-view-multicusine-restaurant-ukkadam/order
# https://www.zomato.com/coimbatore/famous-jigarthanda-ganapathy/order
# https://www.zomato.com/coimbatore/the-biryani-life-rs-puram/order
# https://www.zomato.com/coimbatore/feel-well-rs-puram/order
# https://www.zomato.com/coimbatore/the-london-shakes-2-saibaba-colony/order
# https://www.zomato.com/coimbatore/imi-biriyani-hut-1-peelamedu/order
# https://www.zomato.com/coimbatore/3-monkeys-cafe-saibaba-colony/order
# https://www.zomato.com/coimbatore/hotel-sri-madurai-meenakshi-peelamedu/order
# https://www.zomato.com/coimbatore/just-bake-peelamedu/order
# https://www.zomato.com/coimbatore/famous-biryani-house-1-gandhipuram/order
# https://www.zomato.com/coimbatore/original-nellai-periya-lala-corner-sweets-gandhipuram/order
# https://www.zomato.com/coimbatore/hidden-fork-peelamedu/order
# https://www.zomato.com/coimbatore/abs-absolute-barbecue-lakshmi-mills/order
# https://www.zomato.com/coimbatore/kovai-angatha-briyani-saibaba-colony/order
# https://www.zomato.com/coimbatore/kolapasi-peelamedu/order
# https://www.zomato.com/coimbatore/fb-cakes-ganapathy/order
# https://www.zomato.com/coimbatore/peking-rs-puram/order
# https://www.zomato.com/coimbatore/famous-jigarthanda-ramanathapuram/order
# https://www.zomato.com/coimbatore/chai-n-gupshup-rs-puram/order
# https://www.zomato.com/coimbatore/fox-and-crow-peelamedu/order
# https://www.zomato.com/coimbatore/bamboo-pan-asian-town-hall/order
# https://www.zomato.com/coimbatore/nanis-kitchen-town-hall/order
# https://www.zomato.com/coimbatore/shero-home-sambar-poriyal-rasam-ganapathy/order
# https://www.zomato.com/coimbatore/velan-kaappi-race-course/order
# https://www.zomato.com/coimbatore/hotel-annalakshmi-race-course/order
# https://www.zomato.com/coimbatore/ajmeer-biriyani-4-town-hall/order
# https://www.zomato.com/coimbatore/big-fat-burger-1-peelamedu/order
# https://www.zomato.com/coimbatore/zero-cals-1-peelamedu/order
# https://www.zomato.com/coimbatore/mani-mess-saibaba-colony/order
# https://www.zomato.com/coimbatore/elai-parotta-sivanadha-colony/order
# https://www.zomato.com/coimbatore/shree-kulfi-rs-puram/order
# https://www.zomato.com/coimbatore/bellys-thick-shake-rs-puram/order
# https://www.zomato.com/coimbatore/the-cascade-restaurant-peelamedu/order
# https://www.zomato.com/coimbatore/sweet-truth-cake-and-desserts-rs-puram/order
# https://www.zomato.com/coimbatore/ashok-coconut-sharbad-rs-puram/order
# https://www.zomato.com/coimbatore/foodville-rs-puram/order
# https://www.zomato.com/coimbatore/mr-kovai-chettinadu-restaurant-peelamedu/order
# https://www.zomato.com/coimbatore/baskin-robbins-2-rs-puram/order
# https://www.zomato.com/coimbatore/big-belly-deli-1-saibaba-colony/order
# https://www.zomato.com/coimbatore/browse-n-joy-sivanadha-colony/order
# https://www.zomato.com/coimbatore/fresh-bakes-peelamedu/order
# https://www.zomato.com/coimbatore/fruit-shop-on-greams-road-race-course/order
# https://www.zomato.com/coimbatore/cafe-coffee-day-race-course/order
# https://www.zomato.com/coimbatore/hotel-shri-chola-3-saibaba-colony/order
# https://www.zomato.com/coimbatore/on-the-go-race-course/order
# https://www.zomato.com/coimbatore/tapriwala-the-contemporary-tea-cafe-rs-puram/order
# https://www.zomato.com/coimbatore/suchow-chinese-restaurant-ganapathy/order
# https://www.zomato.com/coimbatore/rock-stone-ice-cream-factory-peelamedu/order
# https://www.zomato.com/coimbatore/hot-cheese-pizza-saibaba-colony/order
# https://www.zomato.com/coimbatore/leandra-ramanathapuram/order
# https://www.zomato.com/coimbatore/refuel-peelamedu/order
# https://www.zomato.com/coimbatore/dawn-coffee-shop-peelamedu/order
# https://www.zomato.com/coimbatore/suna-pana-007-ukkadam/order
# https://www.zomato.com/coimbatore/aachi-foods-rs-puram/order
# https://www.zomato.com/coimbatore/caf%C3%A9-cakebee-saibaba-colony/order
# https://www.zomato.com/coimbatore/cakes-by-chocolates-gandhipuram/order
# https://www.zomato.com/coimbatore/cream-centre-race-course/order
# https://www.zomato.com/coimbatore/sri-balaji-homely-mess-rs-puram/order
# https://www.zomato.com/coimbatore/aryaas-gandhipuram/order
# https://www.zomato.com/coimbatore/firangi-bake-rs-puram/order
# https://www.zomato.com/coimbatore/idc-kitchen-rs-puram/order
# https://www.zomato.com/coimbatore/seasons-rs-puram/order
# https://www.zomato.com/coimbatore/superstar-pizza-saibaba-colony/order
# https://www.zomato.com/coimbatore/hotel-milagu-rasam-lakshmi-mills/order
# https://www.zomato.com/coimbatore/queen-india-biryani-corner-ganapathy/order
# https://www.zomato.com/coimbatore/sai-brindhavan-ramanathapuram/order
# https://www.zomato.com/coimbatore/kites-cafe-1-peelamedu/order
# https://www.zomato.com/coimbatore/siraj-biriyani-ukkadam/order
# https://www.zomato.com/coimbatore/tiffin-house-town-hall/order
# https://www.zomato.com/coimbatore/the-sandwich-point-1-peelamedu/order
# https://www.zomato.com/coimbatore/hotel-aryaas-town-hall/order
# https://www.zomato.com/coimbatore/kr-bakes-1-saibaba-colony/order
# https://www.zomato.com/coimbatore/easwari-chinese-fast-food-peelamedu/order
# https://www.zomato.com/coimbatore/s-a-p-book-stall-and-beeda-stall-rs-puram/order
# https://www.zomato.com/coimbatore/dil-se-rs-puram/order
# https://www.zomato.com/coimbatore/madurai-jigarthanda-gandhipuram/order
# https://www.zomato.com/coimbatore/the-lassi-corner-rs-puram/order
# https://www.zomato.com/coimbatore/selvamani-sweets-town-hall/order
# https://www.zomato.com/coimbatore/idly2roti-peelamedu/order
# https://www.zomato.com/coimbatore/gustovita-nehru-stadium/order
# https://www.zomato.com/coimbatore/orignal-nellai-periya-lala-corner-sweets-gandhipuram/order
# https://www.zomato.com/coimbatore/drunken-monkey-saibaba-colony/order
# https://www.zomato.com/coimbatore/cake-cafe-peelamedu/order
# https://www.zomato.com/coimbatore/zucceria-1-rs-puram/order
# https://www.zomato.com/coimbatore/hotel-biriyani-durbar-ganapathy/order
# https://www.zomato.com/coimbatore/khan-saheb-grills-and-rolls-rs-puram/order
# https://www.zomato.com/coimbatore/muhammeds-five-star-biriyani-ramanathapuram/order
# https://www.zomato.com/coimbatore/chicking-rs-puram/order
# https://www.zomato.com/coimbatore/hotel-annalakshmi-lakshmi-mills/order
# https://www.zomato.com/coimbatore/kebabq-peelamedu/order
# https://www.zomato.com/coimbatore/noruks-ramanathapuram/order
# https://www.zomato.com/coimbatore/kulfistan-saibaba-colony/order
# https://www.zomato.com/coimbatore/rice-n-spice-gandhipuram/order
# https://www.zomato.com/coimbatore/balle-balle-saibaba-colony/order
# https://www.zomato.com/coimbatore/the-baby-chef-1-ganapathy/order
# https://www.zomato.com/coimbatore/rolling-dough-cafe-peelamedu/order
# https://www.zomato.com/coimbatore/bhatijas-kitchen-rs-puram/order
# https://www.zomato.com/coimbatore/murugan-tiffin-house-peelamedu/order
# https://www.zomato.com/coimbatore/pizza-time-kavundampalayam/order
# https://www.zomato.com/coimbatore/blenders-inc-rs-puram/order
# https://www.zomato.com/coimbatore/covai-coffee-desk-rs-puram/order
# https://www.zomato.com/coimbatore/madurai-vilakkuthoon-hanifa-jigarthanda-gandhipuram/order
# https://www.zomato.com/coimbatore/cookie-man-rs-puram/order
# https://www.zomato.com/coimbatore/biryani-dekshaaa-ganapathy/order
# https://www.zomato.com/coimbatore/urban-treats-ramanathapuram/order
# https://www.zomato.com/coimbatore/cafe-totaram-race-course/order
# https://www.zomato.com/ThatsYFood/order
# https://www.zomato.com/coimbatore/waffles-and-cream-saibaba-colony/order
# https://www.zomato.com/coimbatore/dot-berrys-rs-puram/order
# https://www.zomato.com/coimbatore/sree-annapoorna-sweets-snacks-saibaba-colony/order
# https://www.zomato.com/coimbatore/jacket-potatoes-english-foodbar-peelamedu/order
# https://www.zomato.com/coimbatore/eyargai-biriyani-mess-saravanampatty/order
# https://www.zomato.com/coimbatore/roll-over-ice-creams-peelamedu/order

# %%
import numpy as np
pd.DataFrame(
    np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
    columns=['lat', 'lon'])
# Out:
#            lat         lon
# 0    37.783697 -122.425911
# 1    37.750346 -122.422913
# 2    37.762464 -122.355515
# 3    37.747327 -122.414125
# 4    37.785296 -122.394791
# ..         ...         ...
# 995  37.741782 -122.404050
# 996  37.750200 -122.416463
# 997  37.738763 -122.371150
# 998  37.800133 -122.390398
# 999  37.753185 -122.398214
#
# [1000 rows x 2 columns]

# %%
np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4]
# Out:
# array([[  37.7510167 , -122.40383203],
#        [  37.76164541, -122.42768226],
#        [  37.75976577, -122.40345264],
#        ...,
#        [  37.77018811, -122.38357172],
#        [  37.74881518, -122.41823268],
#        [  37.80165202, -122.39253011]])
